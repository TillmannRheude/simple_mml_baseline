# %%
import signal
import wandb
import torch
import os 

import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
from hydra import compose, initialize

from codefiles.helpers import is_running_in_notebook  # for reloading modules instead of restarting kernel
if is_running_in_notebook():
    from codefiles import helpers
    import importlib
    importlib.reload(helpers)
from codefiles.helpers import set_all_seeds, signal_handler, build_model, build_lightningmodule, build_datamodule

os.environ["WANDB_SILENT"] = "true"
torch.set_float32_matmul_precision("high")

def main(cfg) -> None:
    wandb.finish()
    # set_all_seeds(seed=cfg.seed)
    wandb.init(
        project=cfg.wandb.project,
        group=None if cfg.wandb.group == "None" else cfg.wandb.group,
        config={key: value for key, value in cfg.items()},
    )

    model = build_model(cfg)
    lightningmodule = build_lightningmodule(cfg, model)
    datamodule = build_datamodule(cfg)

    trainer = pl.Trainer(
        logger=WandbLogger(project=cfg.wandb.project, dir="wandb/"),
        log_every_n_steps=1,
        accelerator='gpu',
        devices=1,
        max_epochs=cfg.max_epochs,
        precision=cfg.precision
    )

    trainer.fit(lightningmodule, datamodule)
    wandb.finish()

if __name__ == "__main__":
    CONFIG_NAME = "config"
    signal.signal(signal.SIGINT, signal_handler)
    with initialize(version_base="1.1", config_path="config"):
        cfg = compose(config_name=f"{CONFIG_NAME}")
    main(cfg)
# Out:
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/transformers/modeling_utils.py:1035: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(resolved_archive_file, map_location="cpu")
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/utilities/parsing.py:208: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 50
#      48 with initialize(version_base="1.1", config_path="config"):
#      49     cfg = compose(config_name=f"{CONFIG_NAME}")
# ---> 50 main(cfg)
#
# Cell In[1], line 33, in main(cfg)
#      30 lightningmodule = build_lightningmodule(cfg, model)
#      31 datamodule = build_datamodule(cfg)
# ---> 33 trainer = pl.Trainer(
#      34     logger=WandbLogger(project=cfg.wandb.project, dir="wandb/"),
#      35     log_every_n_steps=1,
#      36     accelerator='gpu',
#      37     devices=1,
#      38     max_epochs=cfg.max_epochs,
#      39     precision=cfg.precision
#      40 )
#      42 trainer.fit(lightningmodule, datamodule)
#      43 wandb.finish()
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/utilities/argparse.py:70, in _defaults_from_env_vars.<locals>.insert_env_defaults(self, *args, **kwargs)
#      67 kwargs = dict(list(env_variables.items()) + list(kwargs.items()))
#      69 # all args were already moved to kwargs
# ---> 70 return fn(self, **kwargs)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:395, in Trainer.__init__(self, accelerator, strategy, devices, num_nodes, precision, logger, callbacks, fast_dev_run, max_epochs, min_epochs, max_steps, min_steps, max_time, limit_train_batches, limit_val_batches, limit_test_batches, limit_predict_batches, overfit_batches, val_check_interval, check_val_every_n_epoch, num_sanity_val_steps, log_every_n_steps, enable_checkpointing, enable_progress_bar, enable_model_summary, accumulate_grad_batches, gradient_clip_val, gradient_clip_algorithm, deterministic, benchmark, inference_mode, use_distributed_sampler, profiler, detect_anomaly, barebones, plugins, sync_batchnorm, reload_dataloaders_every_n_epochs, default_root_dir)
#     392 # init connectors
#     393 self._data_connector = _DataConnector(self)
# --> 395 self._accelerator_connector = _AcceleratorConnector(
#     396     devices=devices,
#     397     accelerator=accelerator,
#     398     strategy=strategy,
#     399     num_nodes=num_nodes,
#     400     sync_batchnorm=sync_batchnorm,
#     401     benchmark=benchmark,
#     402     use_distributed_sampler=use_distributed_sampler,
#     403     deterministic=deterministic,
#     404     precision=precision,
#     405     plugins=plugins,
#     406 )
#     407 self._logger_connector = _LoggerConnector(self)
#     408 self._callback_connector = _CallbackConnector(self)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:130, in _AcceleratorConnector.__init__(self, devices, num_nodes, accelerator, strategy, plugins, precision, sync_batchnorm, benchmark, use_distributed_sampler, deterministic)
#     127 self._layer_sync: Optional[LayerSync] = TorchSyncBatchNorm() if sync_batchnorm else None
#     128 self.checkpoint_io: Optional[CheckpointIO] = None
# --> 130 self._check_config_and_set_final_flags(
#     131     strategy=strategy,
#     132     accelerator=accelerator,
#     133     precision=precision,
#     134     plugins=plugins,
#     135     sync_batchnorm=sync_batchnorm,
#     136 )
#     138 # 2. Instantiate Accelerator
#     139 # handle `auto`, `None` and `gpu`
#     140 if self._accelerator_flag == "auto":
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:225, in _AcceleratorConnector._check_config_and_set_final_flags(self, strategy, accelerator, precision, plugins, sync_batchnorm)
#     218     raise ValueError(
#     219         f"You set `strategy={strategy}` but strategies from the DDP family are not supported on the"
#     220         f" MPS accelerator. Either explicitly set `accelerator='cpu'` or change the strategy."
#     221     )
#     223 self._accelerator_flag = accelerator
# --> 225 precision_flag = _convert_precision_to_unified_args(precision)
#     227 if plugins:
#     228     plugins_flags_types: Dict[str, int] = Counter()
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/lightning_fabric/connector.py:565, in _convert_precision_to_unified_args(precision)
#     561 supported_precision = (
#     562     get_args(_PRECISION_INPUT_STR) + get_args(_PRECISION_INPUT_INT) + get_args(_PRECISION_INPUT_STR_ALIAS)
#     563 )
#     564 if precision not in supported_precision:
# --> 565     raise ValueError(f"Precision {repr(precision)} is invalid. Allowed precision values: {supported_precision}")
#     567 precision = str(precision)  # convert int flags to str here to enable the legacy-conversion below
#     569 if precision in get_args(_PRECISION_INPUT_STR_ALIAS):
#
# ValueError: Precision 'float32' is invalid. Allowed precision values: ('transformer-engine', 'transformer-engine-float16', '16-true', '16-mixed', 'bf16-true', 'bf16-mixed', '32-true', '64-true', 64, 32, 16, '64', '32', '16', 'bf16')
