# %%
import signal
import wandb
import torch
import os 

import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
from hydra import compose, initialize

from codefiles.helpers import is_running_in_notebook  # for reloading modules instead of restarting kernel
if is_running_in_notebook():
    from codefiles import helpers
    import importlib
    importlib.reload(helpers)
from codefiles.helpers import set_all_seeds, signal_handler, build_model, build_lightningmodule, build_datamodule

os.environ["WANDB_SILENT"] = "true"
torch.set_float32_matmul_precision("high")

def main(cfg) -> None:
    wandb.finish()
    set_all_seeds(seed=cfg.seed)
    wandb.init(
        project=cfg.wandb.project,
        group=None if cfg.wandb.group == "None" else cfg.wandb.group,
        config={key: value for key, value in cfg.items()},
    )

    model = build_model(cfg)
    lightningmodule = build_lightningmodule(cfg, model)
    datamodule = build_datamodule(cfg)

    trainer = pl.Trainer(
        logger=WandbLogger(project=cfg.wandb.project, dir="wandb/"),
        log_every_n_steps=1,
        accelerator='gpu',
        devices=1,
        max_epochs=cfg.max_epochs,
        precision=cfg.precision
    )

    trainer.fit(lightningmodule, datamodule)
    wandb.finish()

if __name__ == "__main__":
    CONFIG_NAME = "config"
    signal.signal(signal.SIGINT, signal_handler)
    with initialize(version_base="1.1", config_path="config"):
        cfg = compose(config_name=f"{CONFIG_NAME}")
    main(cfg)
# Out:
# Seed set to 420
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/utilities/parsing.py:208: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/py ...
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/loggers/wandb.py:396: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# total_samples: 60000 / 60000
# no_missing: 36000 / 60000
# 1_missing: 24000 / 60000
# modality_0_missing: 11956 / 60000
# modality_1_missing: 12044 / 60000
# total_samples: 10000 / 10000
# no_missing: 6000 / 10000
# 1_missing: 4000 / 10000
# modality_0_missing: 1968 / 10000
# modality_1_missing: 2032 / 10000
#   | Name      | Type                       | Params | Mode
# -----------------------------------------------------------------
# 0 | model     | Multimodal_Architecture    | 3.1 M  | train
# 1 | loss      | CrossEntropyLoss           | 0      | train
# 2 | acc_train | MulticlassAccuracy         | 0      | train
# 3 | acc_val   | MulticlassAccuracy         | 0      | train
# 4 | acc_test  | MulticlassAccuracy         | 0      | train
# 5 | ece       | MulticlassCalibrationError | 0      | train
# 6 | mce       | MulticlassCalibrationError | 0      | train
# 7 | rmsce     | MulticlassCalibrationError | 0      | train
# -----------------------------------------------------------------
# 3.1 M     Trainable params
# 0         Non-trainable params
# 3.1 M     Total params
# 12.524    Total estimated model params size (MB)
# 84        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# tensor([[    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-0.4102,  2.2656,  2.7969,  2.6406, -4.4375,  2.7344, -2.1094,  0.6367,
#           1.8906, -2.9531],
#         [-2.0469,  5.0938,  2.8906,  2.6250, -4.1250,  2.2031, -1.6562, -0.4883,
#           1.5625, -2.3281],
#         [-1.2734,  0.3086,  3.1250,  0.6211, -3.7031,  5.2188, -0.3633, -2.0938,
#           1.6484,  1.2109],
#         [-2.1875,  2.0625,  1.6172,  2.5781, -3.5781,  0.5664, -1.2109, -0.6523,
#           2.0625, -2.3594],
#         [-0.5469,  4.0000,  2.7812,  1.8125,  0.5273, -1.7891, -1.9375, -5.6875,
#           0.6523, -0.8672],
#         [-2.6875,  2.8750,  2.0938,  0.3262, -3.6250,  2.6875,  1.0703, -2.2500,
#           1.3125, -1.5469],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-2.2031,  5.4688,  4.5938,  1.5234, -3.2969,  1.7031, -1.1953, -1.1250,
#           1.8672, -1.2031],
#         [-2.4531,  0.9102,  1.8828,  0.8789, -4.6250,  3.2812, -1.5938, -1.3281,
#           3.7188, -1.6172],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-3.4219,  6.3750,  5.3750,  2.5625, -3.5781,  3.3125,  0.8594, -1.1094,
#           1.1094, -0.9727],
#         [-1.1719, -1.6875,  0.9727,  0.7461, -3.2188,  3.5156, -0.6367, -0.6133,
#           2.8125,  0.6445],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-3.4219,  3.8125,  1.7578,  2.2969, -2.8438, -1.6406, -0.8594, -2.8125,
#           1.0625, -1.6406],
#         [ 0.9141, -0.8984,  1.2578, -1.6719, -4.5312,  5.0312, -2.4062, -4.1250,
#           1.4922,  2.4531],
#         [-0.9180, -0.3242,  0.1260, -0.5430, -3.0469,  4.1875,  0.1953,  1.1875,
#           1.2266,  1.2031],
#         [-4.0938,  2.9531,  4.0625,  1.2109, -3.1094,  4.8125,  1.3281, -3.9062,
#           1.5391, -0.6523],
#         [-3.1719,  2.0156,  2.6094,  2.5781, -4.6875,  0.9688,  1.3828,  0.3945,
#           2.4688,  2.0469],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.0781,  4.7500,  3.2656,  1.8672, -4.4375,  2.3750, -2.3594,  0.0938,
#           1.2188, -2.4688],
#         [-1.3750,  0.6602,  1.7109,  1.0312, -3.6562,  3.0469, -1.1562, -0.1943,
#           2.4844, -1.8672],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [ 1.2422, -0.3809,  2.5469,  1.2344, -3.8125,  5.9062, -0.3418, -2.1250,
#           1.2578,  1.8203],
#         [-2.8906,  5.3438,  4.5000,  1.4922, -0.7617,  2.5156, -0.0515, -5.7500,
#           1.1406, -1.9062],
#         [-1.3906,  4.8125,  4.5312,  1.0547, -3.9375,  4.8438, -1.1875, -0.2139,
#           1.8125, -2.9219],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-4.4375,  3.4688,  2.4375,  2.4219, -1.6172,  1.2656, -0.2100, -2.6406,
#           1.0703, -2.3594],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.3125,  2.5312,  2.3281,  2.9531, -5.7500,  4.8750,  0.4707, -0.7812,
#           1.1562,  0.1670],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-3.0000,  2.9844,  1.6016,  0.9219, -5.0312,  3.0781,  0.4902, -0.1396,
#           2.1719, -0.2217],
#         [-3.4688,  0.9219,  1.9219,  1.6953, -3.4531,  1.2500, -0.1011, -0.2471,
#           2.2500, -1.1875],
#         [-3.8750,  2.9844,  1.6875,  0.0811, -2.5312,  2.3594,  1.5938, -2.4531,
#           1.4062, -1.6797],
#         [-3.3281,  1.1641,  0.7109,  0.8047, -5.5312,  1.2734,  0.1240,  0.3203,
#           1.5391, -0.4746],
#         [-2.2500,  2.8125,  3.5938,  2.2969, -4.7500,  3.9531, -0.5820, -0.8086,
#           2.0156, -2.5469],
#         [-1.7266,  1.5547,  1.3516,  0.8242, -3.0469,  2.0469, -1.1953, -0.3516,
#           2.0469, -2.1250],
#         [-2.7188,  1.3438,  1.7656,  1.9219, -2.0312,  0.8438, -0.5586, -0.3242,
#           1.9766, -0.6289],
#         [-1.7969, -0.4785,  2.1094,  1.1641, -3.6562,  3.3594,  0.3105, -2.8281,
#           0.9883,  2.1875],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-3.4844,  1.2656,  1.3359, -0.3789, -4.1875,  2.6875, -0.5078, -0.2217,
#           2.0312, -2.2812],
#         [-0.4355,  1.1875,  1.0234, -0.7930, -6.9375,  4.5625, -1.7734, -0.7109,
#           0.7695,  3.0469],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.4922, -0.5742,  0.6172,  1.0781, -6.5938,  3.4062,  0.7188,  1.1562,
#           0.5859,  1.7578],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-2.3906, -0.1260,  1.4141,  0.3496, -3.5781,  0.9492, -1.3516, -0.9531,
#           2.6562, -1.5312],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-2.4531,  2.2656,  2.9062,  1.2500, -3.5469,  0.9531, -0.4590, -0.8398,
#           2.5938, -1.7031],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [ 2.2969,  1.7422,  3.3594,  2.1406, -4.9375,  5.7500, -1.0000, -0.0248,
#           0.7656,  1.8516],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan]], device='cuda:0', dtype=torch.bfloat16)
# tensor([[-0.9570,  2.9688,  2.5938,  3.0938, -5.0000,  0.7930, -2.4688,  1.2891,
#           1.8125, -3.0312],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-2.0469,  4.9062,  4.5938,  2.8281, -3.9531,  3.3750,  0.0811, -2.7969,
#           0.5742, -2.4219],
#         [-2.8281,  3.0156,  1.7500,  1.9297, -4.0938,  0.9805, -0.3418, -1.6562,
#           1.6484, -0.7773],
#         [ 1.8281,  0.2891,  2.8438,  1.9141, -4.7812,  8.1875, -0.9883, -0.1279,
#          -0.6445,  2.2344],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-2.8125,  4.9062,  3.0312,  1.6953, -3.3125,  0.3613, -1.4219, -3.7188,
#           1.7031, -2.8438],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-3.3594,  3.6406,  3.8125,  2.7656, -4.0625,  4.3125,  0.0457, -3.0781,
#           1.8906, -0.5586],
#         [-2.4219, -0.5859,  1.6719,  0.8633, -2.6250,  1.7812, -0.4707, -0.8867,
#           2.9062, -3.1250],
#         [-2.7031,  4.7188,  3.6875,  2.1562, -2.9219,  3.5469,  0.1196, -1.1562,
#           1.2812, -2.7812],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.9766, -1.2891,  0.3320, -0.6641, -6.8750,  3.8750,  0.0957, -0.4902,
#           1.8047,  1.8438],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-2.6562,  5.3750,  4.5000,  2.8906, -2.5000,  0.8867, -0.1602, -2.6406,
#           1.2031, -4.6875],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-4.8438,  5.3750,  3.9844,  1.6641, -4.3125,  2.0469,  1.1562, -0.3438,
#           1.9531, -1.9766],
#         [ 0.6406,  3.2188,  2.5156,  1.6094, -6.7812,  5.7500,  0.5469, -1.4766,
#           1.3047,  1.8047],
#         [-2.2031,  2.0156,  2.1094, -0.2227, -4.1875,  2.4062, -0.3809, -0.9844,
#           2.6875, -2.7656],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-3.3125, -0.1021,  1.9609,  1.1094, -3.7656,  1.6094, -0.4355, -0.9258,
#           3.4844, -1.6719],
#         [-2.3594,  2.9844,  4.1250,  3.5938, -3.6875,  3.4531, -0.5469, -2.8125,
#           0.7383, -1.4453],
#         [-1.0000,  0.2207,  0.0298, -1.2656, -7.0938,  4.8750, -0.4473,  0.7070,
#          -0.8008,  3.8281],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-0.6367,  4.2188,  5.5000,  1.8984, -3.3281,  4.1250,  0.0162, -3.3594,
#           1.7891, -2.6094],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.3984,  2.1562,  3.7656,  1.4141, -4.4688,  3.5469, -1.4688, -0.6914,
#           2.6875, -0.5742],
#         [-1.4453,  3.1875,  3.0938,  2.4062, -4.6562,  2.5156, -1.4219,  0.6641,
#           1.3906, -2.5938],
#         [-0.1855,  0.8320,  0.9219, -1.0859, -6.2500,  6.6250, -0.2910,  1.1328,
#           0.2949,  1.5312],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-2.7969,  0.4395,  3.2500,  2.2969, -3.4062,  1.8672,  0.8477, -0.9688,
#           2.7031, -3.1562],
#         [-2.2812,  2.7031,  3.3125,  1.6172, -4.5000,  2.6562, -1.4844, -0.9492,
#           3.0781, -2.8281],
#         [-2.3281,  2.9531,  2.8438,  1.4922, -1.9766,  3.6875, -1.0000, -2.5938,
#           1.4531, -0.4746],
#         [-1.6562,  1.5547,  3.2500,  1.4141, -4.7500,  2.5156, -0.5195, -0.7266,
#           3.2969, -3.0625],
#         [-2.8281,  5.4375,  0.4531,  1.6797, -5.3438,  2.0938, -1.0625, -0.7227,
#           0.7266,  1.6797],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.6875,  3.0469,  1.8125,  2.1875, -2.8438,  3.5156,  0.0554, -1.0547,
#           1.0938, -0.4824],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.7656,  1.1406,  1.6172,  1.6172, -3.8438,  0.9727, -0.7383, -0.7852,
#           2.5781, -0.9727],
#         [-2.1094,  2.1875,  2.0000,  2.3906, -3.5469,  0.6367, -1.3359,  1.5000,
#           2.6562, -2.2344],
#         [-2.9062,  3.5156,  3.2969,  0.7344, -3.1406,  3.4375, -0.9805, -2.3906,
#           0.9727, -0.9336],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-5.0312,  5.3750,  2.5938,  1.3281, -2.2344,  2.2188,  0.5938, -2.6875,
#           1.1016, -2.2500],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-0.5312, -0.8047,  1.5703,  0.6562, -6.7500,  4.0312, -0.7383, -1.9609,
#           2.2812,  1.7578],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.0781,  3.0938,  4.4688,  2.1250, -3.0156,  3.7031, -1.8906, -3.0781,
#           2.2031, -1.1719],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-4.3125,  4.6562,  4.8750,  4.5938, -3.5000,  3.2344,  0.5078, -5.6250,
#           1.5859, -0.2656],
#         [-0.6406,  3.0781,  0.8516, -0.7500, -3.6250,  4.1875,  1.5625, -2.3750,
#          -1.3438,  1.4688],
#         [-1.1172,  3.3906,  2.5469,  2.2812, -4.4375,  5.0938,  0.6758, -3.0156,
#           1.3203, -0.7422],
#         [-2.4688,  1.6875,  4.5312,  3.7656, -2.8125,  2.2344, -0.6641, -2.2812,
#           2.0625, -2.9062],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [    nan,     nan,     nan,     nan,     nan,     nan,     nan,     nan,
#              nan,     nan],
#         [-1.6875,  1.2109,  0.6328, -0.8945, -4.6250,  3.8594, -1.8906, -0.8867,
#           3.0156, -1.0703]], device='cuda:0', dtype=torch.bfloat16)

# %%
import torch 

x = torch.randn(64, 1, 50)
x[0, :, :] = torch.nan

src_mask = torch.isnan(x).any(2)
src_mask
# Out:
# tensor([[ True],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False]])
