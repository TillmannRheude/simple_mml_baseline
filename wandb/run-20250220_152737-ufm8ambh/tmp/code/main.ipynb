# %%
import signal
import wandb
import torch
import os 

import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
from hydra import compose, initialize

from codefiles.helpers import is_running_in_notebook  # for reloading modules instead of restarting kernel
if is_running_in_notebook():
    from codefiles import helpers
    import importlib
    importlib.reload(helpers)
from codefiles.helpers import set_all_seeds, signal_handler, build_model, build_lightningmodule, build_datamodule

os.environ["WANDB_SILENT"] = "true"
torch.set_float32_matmul_precision("high")

def main(cfg) -> None:
    wandb.finish()
    set_all_seeds(seed=cfg.seed)
    wandb.init(
        project=cfg.wandb.project,
        group=None if cfg.wandb.group == "None" else cfg.wandb.group,
        config={key: value for key, value in cfg.items()},
    )

    model = build_model(cfg)
    lightningmodule = build_lightningmodule(cfg, model)
    datamodule = build_datamodule(cfg)

    trainer = pl.Trainer(
        logger=WandbLogger(project=cfg.wandb.project, dir="wandb/"),
        log_every_n_steps=1,
        accelerator='gpu',
        devices=1,
        max_epochs=cfg.max_epochs,
        precision=cfg.precision
    )

    trainer.fit(lightningmodule, datamodule)
    wandb.finish()

if __name__ == "__main__":
    CONFIG_NAME = "config"
    signal.signal(signal.SIGINT, signal_handler)
    with initialize(version_base="1.1", config_path="config"):
        cfg = compose(config_name=f"{CONFIG_NAME}")
    main(cfg)
# Out:
# Seed set to 420
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/utilities/parsing.py:208: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/py ...
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/pytorch_lightning/loggers/wandb.py:396: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# total_samples: 60000 / 60000
# no_missing: 54000 / 60000
# 1_missing: 6000 / 60000
# modality_0_missing: 2992 / 60000
# modality_1_missing: 3008 / 60000
# total_samples: 10000 / 10000
# no_missing: 9000 / 10000
# 1_missing: 1000 / 10000
# modality_0_missing: 481 / 10000
# modality_1_missing: 519 / 10000
#   | Name      | Type                       | Params | Mode
# -----------------------------------------------------------------
# 0 | model     | Multimodal_Architecture    | 5.0 M  | train
# 1 | loss      | CrossEntropyLoss           | 0      | train
# 2 | acc_train | MulticlassAccuracy         | 0      | train
# 3 | acc_val   | MulticlassAccuracy         | 0      | train
# 4 | acc_test  | MulticlassAccuracy         | 0      | train
# 5 | ece       | MulticlassCalibrationError | 0      | train
# 6 | mce       | MulticlassCalibrationError | 0      | train
# 7 | rmsce     | MulticlassCalibrationError | 0      | train
# -----------------------------------------------------------------
# 5.0 M     Trainable params
# 0         Non-trainable params
# 5.0 M     Total params
# 20.033    Total estimated model params size (MB)
# 84        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7f1bdfedf880>> (for post_run_cell):
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/wandb_init.py:441, in _WandbInit._pause_backend(self, *args, **kwargs)
#     439 if self.notebook.save_ipynb():  # type: ignore
#     440     assert self.run is not None
# --> 441     res = self.run.log_code(root=None)
#     442     logger.info("saved code: %s", res)  # type: ignore
#     443 if self.backend.interface is not None:
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:403, in _run_decorator._noop_on_finish.<locals>.decorator_fn.<locals>.wrapper_fn(self, *args, **kwargs)
#     400 @functools.wraps(func)
#     401 def wrapper_fn(self: type[Run], *args: Any, **kwargs: Any) -> Any:
#     402     if not getattr(self, "_is_finished", False):
# --> 403         return func(self, *args, **kwargs)
#     405     default_message = (
#     406         f"Run ({self.id}) is finished. The call to `{func.__name__}` will be ignored. "
#     407         f"Please make sure that you are using an active run."
#     408     )
#     409     resolved_message = message or default_message
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:393, in _run_decorator._attach.<locals>.wrapper(self, *args, **kwargs)
#     391         raise e
#     392     cls._is_attaching = ""
# --> 393 return func(self, *args, **kwargs)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:1226, in Run.log_code(self, root, name, include_fn, exclude_fn)
#    1221     wandb.termwarn(
#    1222         "No relevant files were detected in the specified directory. No code will be logged to your run."
#    1223     )
#    1224     return None
# -> 1226 return self._log_artifact(art)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/wandb_run.py:3319, in Run._log_artifact(self, artifact_or_path, name, type, aliases, tags, distributed_id, finalize, is_user_created, use_after_commit)
#    3317 if self._backend and self._backend.interface:
#    3318     if not self._settings._offline:
# -> 3319         future = self._backend.interface.communicate_artifact(
#    3320             self,
#    3321             artifact,
#    3322             aliases,
#    3323             tags,
#    3324             self.step,
#    3325             finalize=finalize,
#    3326             is_user_created=is_user_created,
#    3327             use_after_commit=use_after_commit,
#    3328         )
#    3329         artifact._set_save_future(future, self._public_api().client)
#    3330     else:
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/interface/interface.py:547, in InterfaceBase.communicate_artifact(self, run, artifact, aliases, tags, history_step, is_user_created, use_after_commit, finalize)
#     545     log_artifact.history_step = history_step
#     546 log_artifact.staging_dir = get_staging_dir()
# --> 547 resp = self._communicate_artifact(log_artifact)
#     548 return resp
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/interface/interface_shared.py:402, in InterfaceShared._communicate_artifact(self, log_artifact)
#     400 def _communicate_artifact(self, log_artifact: pb.LogArtifactRequest) -> Any:
#     401     rec = self._make_request(log_artifact=log_artifact)
# --> 402     return self._communicate_async(rec)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/interface/interface_sock.py:60, in InterfaceSock._communicate_async(self, rec, local)
#      58 if self._process_check and self._process and not self._process.is_alive():
#      59     raise Exception("The wandb backend process has shutdown")
# ---> 60 future = self._router.send_and_receive(rec, local=local)
#      61 return future
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/interface/router.py:92, in MessageRouter.send_and_receive(self, rec, local)
#      89 with self._lock:
#      90     self._pending_reqs[rec.uuid] = future
# ---> 92 self._send_message(rec)
#      94 return future
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/interface/router_sock.py:36, in MessageSockRouter._send_message(self, record)
#      35 def _send_message(self, record: "pb.Record") -> None:
# ---> 36     self._sock_client.send_record_communicate(record)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py:220, in SockClient.send_record_communicate(self, record)
#     218 server_req = spb.ServerRequest()
#     219 server_req.record_communicate.CopyFrom(record)
# --> 220 self.send_server_request(server_req)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py:157, in SockClient.send_server_request(self, msg)
#     156 def send_server_request(self, msg: Any) -> None:
# --> 157     self._send_message(msg)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient._send_message(self, msg)
#     152 header = struct.pack("<BI", ord("W"), raw_size)
#     153 with self._lock:
# --> 154     self._sendall_with_error_handle(header + data)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/wandb/sdk/lib/sock_client.py:132, in SockClient._sendall_with_error_handle(self, data)
#     130 start_time = time.monotonic()
#     131 try:
# --> 132     sent = self._sock.send(data)
#     133     # sent equal to 0 indicates a closed socket
#     134     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
import torch 

x = [torch.randn(64, 1, 50) for _ in range(3)]

x[0][0, 0, :] = torch.nan
src_mask = [torch.isnan(x[i]).view(64, -1).any(1) for i in range(len(x))]
src_mask = torch.stack(src_mask, dim=-1)

transformer_input = torch.cat(x, dim=1)
transformer_input = torch.nan_to_num(transformer_input, nan=0.0)
transformer = torch.nn.TransformerEncoder(
    encoder_layer=torch.nn.TransformerEncoderLayer(d_model=50, nhead=1, batch_first=True),
    num_layers=1
)

out = transformer(transformer_input, src_key_padding_mask=src_mask)
print(out)
# Out:
# tensor([[[ 0.5878,  1.0370,  0.0577,  ...,  2.4688,  0.2920,  0.8688],
#          [-0.8937, -1.8733, -0.8371,  ...,  0.5391,  1.0875,  0.8526],
#          [-0.2392,  0.6350,  1.2745,  ...,  0.4297, -0.5186,  1.5135]],
#
#         [[-0.5598, -0.9236, -0.5886,  ...,  0.7838,  0.1172, -1.3550],
#          [-0.3545,  2.3954,  0.7412,  ...,  0.4345,  1.0314, -0.1962],
#          [-0.8260,  1.2642,  0.7580,  ..., -0.7101, -0.5425, -1.4799]],
#
#         [[-0.6412,  1.2532,  0.3484,  ..., -0.1112,  0.9876, -1.2037],
#          [-0.1714,  1.8958, -0.6057,  ..., -0.5492,  1.6862, -1.4218],
#          [-1.1986, -0.1063, -0.9114,  ..., -0.8649, -2.0944,  1.2927]],
#
#         ...,
#
#         [[-1.2250, -0.0759,  1.6379,  ...,  1.1694,  0.2616, -0.4867],
#          [-0.9156, -0.7569,  0.3610,  ..., -1.5910,  0.4035,  0.0936],
#          [ 0.7059,  0.3685,  2.9654,  ...,  0.6212,  2.0158, -0.7764]],
#
#         [[ 1.4860, -1.0076, -0.9168,  ..., -0.8262, -0.7609, -0.7249],
#          [-1.1037,  0.1358, -1.0061,  ...,  3.1428,  0.6794,  0.5366],
#          [-1.0249, -1.1508,  0.3082,  ...,  0.3041, -0.1092, -0.6430]],
#
#         [[-0.4669,  0.8686,  2.3110,  ..., -0.7613, -0.2752, -0.6593],
#          [-1.6782, -0.4298, -0.6023,  ...,  0.8166, -0.9874, -1.6596],
#          [ 2.0244,  0.9163,  1.2776,  ...,  0.6859, -0.9226,  0.5750]]],
#        grad_fn=<NativeLayerNormBackward0>)
# /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
