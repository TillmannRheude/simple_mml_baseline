# %%
import signal
import wandb
import torch
import os 

import pytorch_lightning as pl
from pytorch_lightning.loggers import WandbLogger
from hydra import compose, initialize

from codefiles.helpers import is_running_in_notebook  # for reloading modules instead of restarting kernel
if is_running_in_notebook():
    from codefiles import helpers
    import importlib
    importlib.reload(helpers)
from codefiles.helpers import set_all_seeds, signal_handler, build_model, build_lightningmodule, build_datamodule

os.environ["WANDB_SILENT"] = "true"
torch.set_float32_matmul_precision("high")

def main(cfg) -> None:
    wandb.finish()
    set_all_seeds(seed=cfg.seed)
    wandb.init(
        project=cfg.wandb.project,
        group=None if cfg.wandb.group == "None" else cfg.wandb.group,
        config={key: value for key, value in cfg.items()},
    )

    model = build_model(cfg)
    lightningmodule = build_lightningmodule(cfg, model)
    datamodule = build_datamodule(cfg)

    trainer = pl.Trainer(
        logger=WandbLogger(project=cfg.wandb.project, dir="wandb/"),
        log_every_n_steps=1,
        accelerator='gpu',
        devices=1,
        max_epochs=cfg.max_epochs,
        precision=cfg.precision
    )

    trainer.fit(lightningmodule, datamodule)
    wandb.finish()

if __name__ == "__main__":
    CONFIG_NAME = "config"
    signal.signal(signal.SIGINT, signal_handler)
    with initialize(version_base="1.1", config_path="config"):
        cfg = compose(config_name=f"{CONFIG_NAME}")
    main(cfg)
# Out:
# Seed set to 420
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 50
#      48 with initialize(version_base="1.1", config_path="config"):
#      49     cfg = compose(config_name=f"{CONFIG_NAME}")
# ---> 50 main(cfg)
#
# Cell In[3], line 30, in main(cfg)
#      23 wandb.init(
#      24     project=cfg.wandb.project,
#      25     group=None if cfg.wandb.group == "None" else cfg.wandb.group,
#      26     config={key: value for key, value in cfg.items()},
#      27 )
#      29 model = build_model(cfg)
# ---> 30 lightningmodule = build_lightningmodule(cfg, model)
#      31 datamodule = build_datamodule(cfg)
#      33 trainer = pl.Trainer(
#      34     logger=WandbLogger(project=cfg.wandb.project, dir="wandb/"),
#      35     log_every_n_steps=1,
#    (...)
#      39     precision=cfg.precision
#      40 )
#
# File /sc-projects/sc-proj-ukb-cvd/projects/simple_mml_baseline_tr/codefiles/helpers.py:167, in build_lightningmodule(cfg, model)
#     161     lightningmodule = MIMIC_Lightning_Module(
#     162         model=model,
#     163         dataset=cfg.dataset,
#     164         params_optimizer={key: value for key, value in cfg.modelname.optimizer.items()},
#     165     )
#     166 elif cfg.dataset == "mnist" or cfg.dataset == "fmnist":
# --> 167     lightningmodule = Synthetic_Lightning_Module(
#     168         model=model,
#     169         dataset=cfg.dataset,
#     170         params_optimizer={key: value for key, value in cfg.modelname.optimizer.items()},
#     171     )
#     172 elif cfg.dataset == "mosi" or cfg.dataset == "mosei":
#     173     lightningmodule = MOSI_Lightning_Module(
#     174         model=model,
#     175         dataset=cfg.dataset,
#     176         params_optimizer={key: value for key, value in cfg.modelname.optimizer.items()},
#     177     )
#
# File /sc-projects/sc-proj-ukb-cvd/projects/simple_mml_baseline_tr/codefiles/lightningmodules/synthetic.py:33, in Synthetic_Lightning_Module.__init__(self, model, params_optimizer, dataset)
#      29 self.model = model
#      31 self.loss = nn.CrossEntropyLoss()
# ---> 33 self.acc_train = MulticlassAccuracy(num_classes=self.model.output_dim)
#      34 self.acc_val = MulticlassAccuracy(num_classes=self.model.output_dim)
#      35 self.acc_test = MulticlassAccuracy(num_classes=self.model.output_dim)
#
# File /sc-projects/sc-proj-ukb-cvd/environments/mml/lib/python3.9/site-packages/torch/nn/modules/module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'Multimodal_Architecture' object has no attribute 'output_dim'
